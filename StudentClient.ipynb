# %% [markdown]
# # Student Client
#
# ### Steps to Run with Reinforcement Agent.
# - 1. Add the RLAgent here
# - 2. Train the RLAgent/ You can train the RLAgent in some other notebook and store the results using pickle library in python. Then you can test your RLAgent with the server.
# - 3. Use the policy to run on the server.
#
# ### DO NOT TRAIN THE MODEL WHILE RUNNING ON THE SERVER!

# %%
import socket
import os
import subprocess
import ast
import pdb
import numpy as np
import time
player = 'amajeti' #enter unique name for your game
s = socket.socket() 
# s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
host = '100.24.254.170' # change ip addres to ip address of your computer or use 'localhost' to practice
port = 9999

s.connect((host, port))
while True:
    data = s.recv(1024)
    if data.decode("utf-8") == 'send':
        s.send(str.encode( player))
        client_response = str(s.recv(20480), "utf-8")
        print(client_response, end="")
        break

while True:
    data = s.recv(20480)
    print(data,end=".")
    if data.decode("utf-8") == f'sendinfo':
        s.send(str.encode("acknowledged_pick"))
        ##Here you will recieve information about the player such as card rank, card suit, stash score, 
        client_response = str(s.recv(20480), "utf-8")
        print(client_response)
        action = np.random.randint(0, 2)
        print("action pick ",action)
        s.send(str.encode( str(action)))
    if data.decode("utf-8") == f'sendaction_for_card_drop':
        s.send(str.encode("acknowledged_drop"))
        ro=str(s.recv(20480), "utf-8")
        ro=ast.literal_eval(ro)
        print("action send for drop")
        print(ro)
        #follow same procedure as abov to send observations to your agent
        ###### Look at the above observations and action in variable action#####
        action = np.random.randint(0, 3)
        s.send(str.encode( str(action)))
        print("action drop",action)
    if data.decode("utf-8") == 'gameover':
        print("Game over wait for others to play and wait for results")
        break
    if data.decode("utf-8") == 'round_over':
        s.send(str.encode("acknowledged_round_over"))
        print('Round over')
        client_response = str(s.recv(20480), "utf-8")
        print(client_response, end="")
# Out:
# Connection established, Names collectedb'sendinfo'.{'Stash Score': 6, 'CardSuit': [1, 4, 1], 'CardRanks': ['C', 'H', 'S'], 'PileRank': '6', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [1, 4, 1, 6], 'CardRanks': ['C', 'H', 'S', 'D']}
# action drop 0
# b'sendinfo'.{'Stash Score': 11, 'CardSuit': [4, 1, 6], 'CardRanks': ['H', 'S', 'D'], 'PileRank': '4', 'PileSuit': 'C'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [4, 1, 6, 6], 'CardRanks': ['H', 'S', 'D', 'H'], 'PileRank': '4', 'PileSuit': 'C'}
# action drop 2
# b'sendinfo'.{'Stash Score': 11, 'CardSuit': [4, 1, 6], 'CardRanks': ['H', 'S', 'H'], 'PileRank': '5', 'PileSuit': 'C'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [4, 1, 6, 7], 'CardRanks': ['H', 'S', 'H', 'S'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 2
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [4, 1, 7], 'CardRanks': ['H', 'S', 'S'], 'PileRank': '6', 'PileSuit': 'H'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [4, 1, 7, 6], 'CardRanks': ['H', 'S', 'S', 'H'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 1
# b'sendinfo'.{'Stash Score': 17, 'CardSuit': [4, 7, 6], 'CardRanks': ['H', 'S', 'H'], 'PileRank': 'A', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [4, 7, 6, 2], 'CardRanks': ['H', 'S', 'H', 'C'], 'PileRank': 'A', 'PileSuit': 'S'}
# action drop 1
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [4, 6, 2], 'CardRanks': ['H', 'H', 'C'], 'PileRank': '2', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [4, 6, 2, 2], 'CardRanks': ['H', 'H', 'C', 'S'], 'PileRank': '7', 'PileSuit': 'S'}
# action drop 2
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [4, 6, 2], 'CardRanks': ['H', 'H', 'S'], 'PileRank': '6', 'PileSuit': 'C'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [4, 6, 2, 5], 'CardRanks': ['H', 'H', 'S', 'D'], 'PileRank': '6', 'PileSuit': 'C'}
# action drop 2
# b'sendinfo'.{'Stash Score': 15, 'CardSuit': [4, 6, 5], 'CardRanks': ['H', 'H', 'D'], 'PileRank': '5', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [4, 6, 5, 4], 'CardRanks': ['H', 'H', 'D', 'D'], 'PileRank': '5', 'PileSuit': 'S'}
# action drop 1
# b'sendinfo'.{'Stash Score': 13, 'CardSuit': [4, 5, 4], 'CardRanks': ['H', 'D', 'D'], 'PileRank': '6', 'PileSuit': 'H'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [4, 5, 4, 3], 'CardRanks': ['H', 'D', 'D', 'C'], 'PileRank': '6', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [5, 4, 3], 'CardRanks': ['D', 'D', 'C'], 'PileRank': '2', 'PileSuit': 'D'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [5, 4, 3, 4], 'CardRanks': ['D', 'D', 'C', 'S'], 'PileRank': '2', 'PileSuit': 'D'}
# action drop 1
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [5, 3, 4], 'CardRanks': ['D', 'C', 'S'], 'PileRank': '2', 'PileSuit': 'C'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [5, 3, 4, 7], 'CardRanks': ['D', 'C', 'S', 'C'], 'PileRank': '2', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.{'Stash Score': 14, 'CardSuit': [3, 4, 7], 'CardRanks': ['C', 'S', 'C'], 'PileRank': '2', 'PileSuit': 'H'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [3, 4, 7, 5], 'CardRanks': ['C', 'S', 'C', 'H'], 'PileRank': '2', 'PileSuit': 'H'}
# action drop 1
# b'round_over'.Round over
# Player: comp1  Score: 0 Stash Score : 0
# Player: amajeti  Score: 15 Stash Score : 15
# b'sendinfo'.{'Stash Score': 9, 'CardSuit': [6, 2, 1], 'CardRanks': ['H', 'S', 'S'], 'PileRank': 'A', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 10, 'CardSuit': [6, 2, 1, 1], 'CardRanks': ['H', 'S', 'S', 'D']}
# action drop 2
# b'sendinfo'.{'Stash Score': 9, 'CardSuit': [6, 2, 1], 'CardRanks': ['H', 'S', 'D'], 'PileRank': '4', 'PileSuit': 'D'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [6, 2, 1, 7], 'CardRanks': ['H', 'S', 'D', 'S'], 'PileRank': '4', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.{'Stash Score': 10, 'CardSuit': [2, 1, 7], 'CardRanks': ['S', 'D', 'S'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [2, 1, 7, 7], 'CardRanks': ['S', 'D', 'S', 'C'], 'PileRank': '6', 'PileSuit': 'H'}
# action drop 2
# b'sendinfo'.{'Stash Score': 10, 'CardSuit': [2, 1, 7], 'CardRanks': ['S', 'D', 'C'], 'PileRank': '3', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 13, 'CardSuit': [2, 1, 7, 3], 'CardRanks': ['S', 'D', 'C', 'S'], 'PileRank': '6', 'PileSuit': 'H'}
# action drop 1
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [2, 7, 3], 'CardRanks': ['S', 'C', 'S'], 'PileRank': '5', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [2, 7, 3, 5], 'CardRanks': ['S', 'C', 'S', 'H'], 'PileRank': '5', 'PileSuit': 'S'}
# action drop 2
# b'sendinfo'.{'Stash Score': 14, 'CardSuit': [2, 7, 5], 'CardRanks': ['S', 'C', 'H'], 'PileRank': '7', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 20, 'CardSuit': [2, 7, 5, 6], 'CardRanks': ['S', 'C', 'H', 'C'], 'PileRank': '7', 'PileSuit': 'S'}
# action drop 1
# b'sendinfo'.{'Stash Score': 13, 'CardSuit': [2, 5, 6], 'CardRanks': ['S', 'H', 'C'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 19, 'CardSuit': [2, 5, 6, 6], 'CardRanks': ['S', 'H', 'C', 'S'], 'PileRank': '7', 'PileSuit': 'S'}
# action drop 1
# b'sendinfo'.{'Stash Score': 14, 'CardSuit': [2, 6, 6], 'CardRanks': ['S', 'C', 'S'], 'PileRank': 'A', 'PileSuit': 'D'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [2, 6, 6, 4], 'CardRanks': ['S', 'C', 'S', 'H'], 'PileRank': 'A', 'PileSuit': 'D'}
# action drop 2
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [2, 6, 4], 'CardRanks': ['S', 'C', 'H'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 15, 'CardSuit': [2, 6, 4, 3], 'CardRanks': ['S', 'C', 'H', 'C'], 'PileRank': '6', 'PileSuit': 'S'}
# action drop 2
# b'sendinfo'.{'Stash Score': 11, 'CardSuit': [2, 6, 3], 'CardRanks': ['S', 'C', 'C'], 'PileRank': '4', 'PileSuit': 'H'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 12, 'CardSuit': [2, 6, 3, 1], 'CardRanks': ['S', 'C', 'C', 'H'], 'PileRank': '4', 'PileSuit': 'H'}
# action drop 1
# b'sendinfo'.{'Stash Score': 6, 'CardSuit': [2, 3, 1], 'CardRanks': ['S', 'C', 'H'], 'PileRank': '7', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 13, 'CardSuit': [2, 3, 1, 7], 'CardRanks': ['S', 'C', 'H', 'C'], 'PileRank': '6', 'PileSuit': 'C'}
# action drop 0
# b'sendinfo'.{'Stash Score': 11, 'CardSuit': [3, 1, 7], 'CardRanks': ['C', 'H', 'C'], 'PileRank': '3', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [3, 1, 7, 3], 'CardRanks': ['C', 'H', 'C', 'D'], 'PileRank': '2', 'PileSuit': 'S'}
# action drop 1
# b'sendinfo'.{'Stash Score': 13, 'CardSuit': [3, 7, 3], 'CardRanks': ['C', 'C', 'D'], 'PileRank': 'A', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [3, 7, 3, 1], 'CardRanks': ['C', 'C', 'D', 'C'], 'PileRank': 'A', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.{'Stash Score': 11, 'CardSuit': [7, 3, 1], 'CardRanks': ['C', 'D', 'C'], 'PileRank': '3', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [7, 3, 1, 3], 'CardRanks': ['C', 'D', 'C', 'C'], 'PileRank': 'A', 'PileSuit': 'H'}
# action drop 0
# b'sendinfo'.{'Stash Score': 7, 'CardSuit': [3, 1, 3], 'CardRanks': ['D', 'C', 'C'], 'PileRank': '2', 'PileSuit': 'H'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 13, 'CardSuit': [3, 1, 3, 6], 'CardRanks': ['D', 'C', 'C', 'D'], 'PileRank': '2', 'PileSuit': 'H'}
# action drop 1
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [3, 3, 6], 'CardRanks': ['D', 'C', 'D'], 'PileRank': '3', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [3, 3, 6, 5], 'CardRanks': ['D', 'C', 'D', 'D'], 'PileRank': '3', 'PileSuit': 'S'}
# action drop 0
# b'sendinfo'.{'Stash Score': 14, 'CardSuit': [3, 6, 5], 'CardRanks': ['C', 'D', 'D'], 'PileRank': '4', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [3, 6, 5, 4], 'CardRanks': ['C', 'D', 'D', 'S'], 'PileRank': '3', 'PileSuit': 'D'}
# action drop 2
# b'sendinfo'.{'Stash Score': 13, 'CardSuit': [3, 6, 4], 'CardRanks': ['C', 'D', 'S'], 'PileRank': '5', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 18, 'CardSuit': [3, 6, 4, 5], 'CardRanks': ['C', 'D', 'S', 'D'], 'PileRank': '3', 'PileSuit': 'D'}
# action drop 1
# b'sendinfo'.{'Stash Score': 12, 'CardSuit': [3, 4, 5], 'CardRanks': ['C', 'S', 'D'], 'PileRank': '2', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 14, 'CardSuit': [3, 4, 5, 2], 'CardRanks': ['C', 'S', 'D', 'D'], 'PileRank': '3', 'PileSuit': 'D'}
# action drop 2
# b'round_over'.Round over
# Player: amajeti  Score: 24 Stash Score : 9
# Player: comp1  Score: 15 Stash Score : 15
# b'sendinfo'.{'Stash Score': 10, 'CardSuit': [2, 7, 1], 'CardRanks': ['C', 'C', 'S'], 'PileRank': '7', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [2, 7, 1, 7], 'CardRanks': ['C', 'C', 'S', 'D']}
# action drop 2
# b'sendinfo'.{'Stash Score': 16, 'CardSuit': [2, 7, 7], 'CardRanks': ['C', 'C', 'D'], 'PileRank': '5', 'PileSuit': 'C'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 2, 'CardSuit': [2], 'CardRanks': ['C'], 'PileRank': '5', 'PileSuit': 'C'}
# action drop 0
# b'round_over'.Round over
# Player: amajeti  Score: 24 Stash Score : 0
# Player: comp1  Score: 23 Stash Score : 8
# b'sendinfo'.{'Stash Score': 11, 'CardSuit': [7, 2, 2], 'CardRanks': ['S', 'C', 'H'], 'PileRank': '6', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 17, 'CardSuit': [7, 2, 2, 6], 'CardRanks': ['S', 'C', 'H', 'S']}
# action drop 1
# b'sendinfo'.{'Stash Score': 15, 'CardSuit': [7, 2, 6], 'CardRanks': ['S', 'H', 'S'], 'PileRank': 'A', 'PileSuit': 'D'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 16, 'CardSuit': [7, 2, 6, 1], 'CardRanks': ['S', 'H', 'S', 'D'], 'PileRank': '2', 'PileSuit': 'C'}
# action drop 2
# b'sendinfo'.{'Stash Score': 10, 'CardSuit': [7, 2, 1], 'CardRanks': ['S', 'H', 'D'], 'PileRank': '5', 'PileSuit': 'D'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 11, 'CardSuit': [7, 2, 1, 1], 'CardRanks': ['S', 'H', 'D', 'H'], 'PileRank': '5', 'PileSuit': 'D'}
# action drop 0
# b'sendinfo'.{'Stash Score': 4, 'CardSuit': [2, 1, 1], 'CardRanks': ['H', 'D', 'H'], 'PileRank': '5', 'PileSuit': 'H'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 7, 'CardSuit': [2, 1, 1, 3], 'CardRanks': ['H', 'D', 'H', 'S'], 'PileRank': '5', 'PileSuit': 'H'}
# action drop 2
# b'sendinfo'.{'Stash Score': 6, 'CardSuit': [2, 1, 3], 'CardRanks': ['H', 'D', 'S'], 'PileRank': '3', 'PileSuit': 'C'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 9, 'CardSuit': [2, 1, 3, 3], 'CardRanks': ['H', 'D', 'S', 'C'], 'PileRank': '5', 'PileSuit': 'H'}
# action drop 1
# b'sendinfo'.{'Stash Score': 8, 'CardSuit': [2, 3, 3], 'CardRanks': ['H', 'S', 'C'], 'PileRank': '5', 'PileSuit': 'S'}
# action pick  1
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 15, 'CardSuit': [2, 3, 3, 7], 'CardRanks': ['H', 'S', 'C', 'C'], 'PileRank': '5', 'PileSuit': 'S'}
# action drop 1
# b'round_over'.Round over
# Player: amajeti  Score: 36 Stash Score : 12
# Player: comp1  Score: 23 Stash Score : 0
# b'sendinfo'.{'Stash Score': 18, 'CardSuit': [6, 6, 6], 'CardRanks': ['C', 'S', 'H'], 'PileRank': '5', 'PileSuit': 'S'}
# action pick  0
# b'sendaction_for_card_drop'.action send for drop
# {'Stash Score': 5, 'CardSuit': [5], 'CardRanks': ['S']}
# action drop 2
# b'round_over'.Round over
# Player: amajeti  Score: 36 Stash Score : 0
# Player: comp1  Score: 35 Stash Score : 12
# b'gameover'.Game over wait for others to play and wait for results
